# %% [markdown]
# # 1. data preparation

# %% [markdown]
# ## 1.1 read train and testb data

# %%
import pandas as pd
import numpy as np

def count_one_ratio(arr):
    counts = arr.value_counts()
    try:
        if counts.sum()<100:
            return 0
        return counts[1]/counts.sum()
    except:
        return 0

train_data = pd.read_csv('../data/full_size/atec_anti_fraud_train.csv',index_col = 0)
testb_data = pd.read_csv('../data/full_size/atec_anti_fraud_test_b.csv',index_col = 0)

# %% [markdown]
# ## 1.2 split data into labeled and unlabeled

# %%
unlabeled_data=(train_data[train_data['label']==-1])
normal_data = train_data[train_data['label']==0]
anormal_data=train_data[train_data['label']==1]
labeled_data = train_data[(train_data['label']==0)|(train_data['label']==1)]

# %% [markdown]
# ## 1.3 train test split

# %%
train_num = int(labeled_data.shape[0]*0.8)
train_x = labeled_data.iloc[:train_num,:].drop(columns=['label'])
train_y = labeled_data.iloc[:train_num,:]['label']
test_x = labeled_data.iloc[train_num:,:].drop(columns=['label'])
test_y = labeled_data.iloc[train_num:,:]['label']

# %% [markdown]
# # 2. generate risk ratio of every feature value

# %%
risk_ratios = {} # key:feature_name,value: list of anormal probabilities for every possible value
for feature in labeled_data.columns[2:]:
    print(feature)
    max_value = labeled_data[feature].max()
    min_value = labeled_data[feature].min()
    value_num = labeled_data[feature].value_counts().shape[0]
    if value_num>10000:
        # guarantee the number in every bin won't be too small
        bins = 1000
        ratio = labeled_data.groupby(pd.cut(labeled_data[feature],np.linspace(min_value-0.1,max_value,bins))).label.mean()
        risk_ratios[feature]=ratio
    else:
        risk_ratios[feature]=labeled_data.groupby(feature).label.agg(count_one_ratio)
# Out:
# f1
# f2
# f3
# f4
# f5
# f6
# f7
# f8
# f9
# f10
# f11
# f12
# f13
# f14
# f15
# f16
# f17
# f18
# f19
# f20
# f21
# f22
# f23
# f24
# f25
# f26
# f27
# f28
# f29
# f30
# f31
# f32
# f33
# f34
# f35
# f36
# f37
# f38
# f39
# f40
# f41
# f42
# f43
# f44
# f45
# f46
# f47
# f48
# f49
# f50
# f51
# f52
# f53
# f54
# f55
# f56
# f57
# f58
# f59
# f60
# f61
# f62
# f63
# f64
# f65
# f66
# f67
# f68
# f69
# f70
# f71
# f72
# f73
# f74
# f75
# f76
# f77
# f78
# f79
# f80
# f81
# f82
# f83
# f84
# f85
# f86
# f87
# f88
# f89
# f90
# f91
# f92
# f93
# f94
# f95
# f96
# f97
# f98
# f99
# f100
# f101
# f102
# f103
# f104
# f105
# f106
# f107
# f108
# f109
# f110
# f111
# f112
# f113
# f114
# f115
# f116
# f117
# f118
# f119
# f120
# f121
# f122
# f123
# f124
# f125
# f126
# f127
# f128
# f129
# f130
# f131
# f132
# f133
# f134
# f135
# f136
# f137
# f138
# f139
# f140
# f141
# f142
# f143
# f144
# f145
# f146
# f147
# f148
# f149
# f150
# f151
# f152
# f153
# f154
# f155
# f156
# f157
# f158
# f159
# f160
# f161
# f162
# f163
# f164
# f165
# f166
# f167
# f168
# f169
# f170
# f171
# f172
# f173
# f174
# f175
# f176
# f177
# f178
# f179
# f180
# f181
# f182
# f183
# f184
# f185
# f186
# f187
# f188
# f189
# f190
# f191
# f192
# f193
# f194
# f195
# f196
# f197
# f198
# f199
# f200
# f201
# f202
# f203
# f204
# f205
# f206
# f207
# f208
# f209
# f210
# f211
# f212
# f213
# f214
# f215
# f216
# f217
# f218
# f219
# f220
# f221
# f222
# f223
# f224
# f225
# f226
# f227
# f228
# f229
# f230
# f231
# f232
# f233
# f234
# f235
# f236
# f237
# f238
# f239
# f240
# f241
# f242
# f243
# f244
# f245
# f246
# f247
# f248
# f249
# f250
# f251
# f252
# f253
# f254
# f255
# f256
# f257
# f258
# f259
# f260
# f261
# f262
# f263
# f264
# f265
# f266
# f267
# f268
# f269
# f270
# f271
# f272
# f273
# f274
# f275
# f276
# f277
# f278
# f279
# f280
# f281
# f282
# f283
# f284
# f285
# f286
# f287
# f288
# f289
# f290
# f291
# f292
# f293
# f294
# f295
# f296
# f297

# %% [markdown]
# ## 2.1 get high risk feature value

# %%
high_risks = {}
for feature,ratios in risk_ratios.items():
    high_risk = ratios[ratios>0.3]
    if not high_risk.empty:
        high_risks[feature]=high_risk

# %%
high_risks.keys()
# Out:
# dict_keys(['f120', 'f147', 'f112', 'f144', 'f52', 'f256', 'f170', 'f22', 'f171', 'f297', 'f111', 'f141', 'f197', 'f276', 'f26', 'f156', 'f268', 'f138', 'f274', 'f140', 'f193', 'f167', 'f155', 'f196', 'f5', 'f83', 'f149', 'f137', 'f23', 'f294', 'f203', 'f122', 'f148', 'f139', 'f267', 'f270', 'f115', 'f295', 'f284', 'f118', 'f82', 'f257', 'f31', 'f29', 'f198', 'f152', 'f189', 'f30', 'f27', 'f143', 'f153', 'f28', 'f293', 'f136', 'f287', 'f86', 'f145', 'f188', 'f142', 'f151', 'f285', 'f201', 'f85', 'f187', 'f275', 'f114', 'f24', 'f191', 'f200', 'f25', 'f146', 'f258', 'f273', 'f119', 'f269', 'f121', 'f150', 'f135', 'f271', 'f255', 'f160', 'f113', 'f277', 'f202', 'f117', 'f190', 'f286', 'f53', 'f169'])

# %%
for x in test_x.iterrows():
    print(x)
    break
# Out:
# <class 'tuple'>

# %% [markdown]
# # 3. prediction and evaluation on test dataset

# %% [markdown]
# ## 3.1 define predict function

# %%
def mannual_predit_proba(X):
    '''
    X should be in shape of (n_samples,n_columns)
    '''
    high_risk_features = high_risk.keys()
    for
