# %%
import pandas as pd
from sklearn import preprocessing
from sklearn import metrics
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
# from gcforest.gcforest import GCForest
from GCForest import *

# %%
# data preprocessing
df = pd.read_csv('../data/full_size/atec_anti_fraud_train.csv',index_col = 0) # read large data
# df = df[df['label']!=-1]
# df = df.fillna(df.mode().iloc[0]) # fill nan with most common value

# %%
df.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, f10eb20f31cf7063ee8bdbd1272214e4d7e0193c8dbce45ad14463036ff95d0a to 41f1fc8de12efaf7b024b4b5aec2b0e4a1cde0ceba2d3fee6d50750b3707a736
# Data columns (total 299 columns):
# label    int64
# date     int64
# f1       int64
# f2       int64
# f3       int64
# f4       int64
# f5       float64
# f6       int64
# f7       int64
# f8       int64
# f9       int64
# f10      int64
# f11      int64
# f12      int64
# f13      int64
# f14      int64
# f15      int64
# f16      int64
# f17      int64
# f18      int64
# f19      int64
# f20      float64
# f21      float64
# f22      float64
# f23      float64
# f24      float64
# f25      float64
# f26      float64
# f27      float64
# f28      float64
# f29      float64
# f30      float64
# f31      float64
# f32      float64
# f33      float64
# f34      float64
# f35      float64
# f36      float64
# f37      float64
# f38      float64
# f39      float64
# f40      float64
# f41      float64
# f42      float64
# f43      float64
# f44      float64
# f45      float64
# f46      float64
# f47      float64
# f48      float64
# f49      float64
# f50      float64
# f51      float64
# f52      float64
# f53      float64
# f54      float64
# f55      float64
# f56      float64
# f57      float64
# f58      float64
# f59      float64
# f60      float64
# f61      float64
# f62      float64
# f63      float64
# f64      float64
# f65      float64
# f66      float64
# f67      float64
# f68      float64
# f69      float64
# f70      float64
# f71      float64
# f72      float64
# f73      float64
# f74      float64
# f75      float64
# f76      float64
# f77      float64
# f78      float64
# f79      float64
# f80      float64
# f81      float64
# f82      float64
# f83      float64
# f84      float64
# f85      float64
# f86      float64
# f87      float64
# f88      float64
# f89      float64
# f90      float64
# f91      float64
# f92      float64
# f93      float64
# f94      float64
# f95      float64
# f96      float64
# f97      float64
# f98      float64
# f99      float64
# f100     float64
# f101     float64
# f102     float64
# f103     float64
# f104     float64
# f105     float64
# f106     float64
# f107     float64
# f108     float64
# f109     float64
# f110     float64
# f111     float64
# f112     float64
# f113     float64
# f114     float64
# f115     float64
# f116     float64
# f117     float64
# f118     float64
# f119     float64
# f120     float64
# f121     float64
# f122     float64
# f123     float64
# f124     float64
# f125     float64
# f126     float64
# f127     float64
# f128     float64
# f129     float64
# f130     float64
# f131     float64
# f132     float64
# f133     float64
# f134     float64
# f135     float64
# f136     float64
# f137     float64
# f138     float64
# f139     float64
# f140     float64
# f141     float64
# f142     float64
# f143     float64
# f144     float64
# f145     float64
# f146     float64
# f147     float64
# f148     float64
# f149     float64
# f150     float64
# f151     float64
# f152     float64
# f153     float64
# f154     float64
# f155     float64
# f156     float64
# f157     float64
# f158     float64
# f159     float64
# f160     float64
# f161     float64
# f162     float64
# f163     float64
# f164     float64
# f165     float64
# f166     float64
# f167     float64
# f168     float64
# f169     float64
# f170     float64
# f171     float64
# f172     float64
# f173     float64
# f174     float64
# f175     float64
# f176     float64
# f177     float64
# f178     float64
# f179     float64
# f180     float64
# f181     float64
# f182     float64
# f183     float64
# f184     float64
# f185     float64
# f186     float64
# f187     float64
# f188     float64
# f189     float64
# f190     float64
# f191     float64
# f192     float64
# f193     float64
# f194     float64
# f195     float64
# f196     float64
# f197     float64
# f198     float64
# f199     float64
# f200     float64
# f201     float64
# f202     float64
# f203     float64
# f204     float64
# f205     float64
# f206     float64
# f207     float64
# f208     float64
# f209     float64
# f210     float64
# f211     float64
# f212     float64
# f213     float64
# f214     float64
# f215     float64
# f216     float64
# f217     float64
# f218     float64
# f219     float64
# f220     float64
# f221     float64
# f222     float64
# f223     float64
# f224     float64
# f225     float64
# f226     float64
# f227     float64
# f228     float64
# f229     float64
# f230     float64
# f231     float64
# f232     float64
# f233     float64
# f234     float64
# f235     float64
# f236     float64
# f237     float64
# f238     float64
# f239     float64
# f240     float64
# f241     float64
# f242     float64
# f243     float64
# f244     float64
# f245     float64
# f246     float64
# f247     float64
# f248     float64
# f249     float64
# f250     float64
# f251     float64
# f252     float64
# f253     float64
# f254     float64
# f255     float64
# f256     float64
# f257     float64
# f258     float64
# f259     float64
# f260     float64
# f261     float64
# f262     float64
# f263     float64
# f264     float64
# f265     float64
# f266     float64
# f267     float64
# f268     float64
# f269     float64
# f270     float64
# f271     float64
# f272     float64
# f273     float64
# f274     float64
# f275     float64
# f276     float64
# f277     float64
# f278     float64
# f279     float64
# f280     float64
# f281     float64
# f282     float64
# f283     float64
# f284     float64
# f285     float64
# f286     float64
# f287     float64
# f288     float64
# f289     float64
# f290     float64
# f291     float64
# f292     float64
# f293     float64
# f294     float64
# f295     float64
# f296     float64
# f297     float64
# dtypes: float64(279), int64(20)
# memory usage: 2.3+ MB

# %%
train_num = int(0.75*df.shape[0])
train_data = df.iloc[:train_num,:] # feature without time
test_data = df.iloc[train_num:,:] # label

train_x = train_data.iloc[:,1:]
train_y = train_data.iloc[:,0]
test_x = test_data.iloc[:,1:]
test_y = test_data.iloc[:,0]

# %%
# set up configuration of gcforest
def get_toy_config():
    config = {}
    ca_config = {}
    ca_config["random_state"] = 0
    ca_config["max_layers"] = 100
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 2
    ca_config["estimators"] = []
    ca_config["estimators"].append(
            {"n_folds": 5, "type": "XGBClassifier", "n_estimators": 10, "max_depth": 5,
             "objective": "binary:logistic", "silent": False, "learning_rate": 0.1} )
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "n_estimators": 10, "max_depth": None, "n_jobs": -1})
    ca_config["estimators"].append({"n_folds": 5, "type": "ExtraTreesClassifier", "n_estimators": 10, "max_depth": None, "n_jobs": -1})
    ca_config["estimators"].append({"n_folds": 5, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
# config = get_toy_config()
# gcf = GCForest(config)
# x_train_enc = gcf.fit_transform(train_x.values,train_y.values)

gcf = gcForest(shape_1X=(1,train_x.shape[1]),window=train_x.shape[1])
gcf.fit_transform(train_x.values,train_y.values)
# Out:
# Slicing Sequence...
# Training MGS Random Forests...
# e:\python352\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# e:\python352\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# Adding/Training Layer, n_layer=1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1a09ad548aaf> in <module>()
#       4
#       5 gcf = gcForest(shape_1X=(1,train_x.shape[1]),window=train_x.shape[1])
# ----> 6 gcf.fit(train_x.values,train_y.values)
#
# E:\competitions\ATEC-Risk\notebook\GCForest.py in fit(self, X, y)
#     124
#     125         mgs_X = self.mg_scanning(X, y)
# --> 126         _ = self.cascade_forest(mgs_X, y)
#     127
#     128     def predict_proba(self, X):
#
# E:\competitions\ATEC-Risk\notebook\GCForest.py in cascade_forest(self, X, y)
#     345
#     346             self.n_layer += 1
# --> 347             prf_crf_pred_ref = self._cascade_layer(X_train, y_train)
#     348             accuracy_ref = self._cascade_evaluation(X_test, y_test)
#     349             feat_arr = self._create_feat_arr(X_train, prf_crf_pred_ref)
#
# E:\competitions\ATEC-Risk\notebook\GCForest.py in _cascade_layer(self, X, y, layer)
#     409             print('Adding/Training Layer, n_layer={}'.format(self.n_layer))
#     410             for irf in range(n_cascadeRF):
# --> 411                 prf.fit(X, y)
#     412                 crf.fit(X, y)
#     413                 setattr(self, '_casprf{}_{}'.format(self.n_layer, irf), prf)
#
# e:\python352\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# e:\python352\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# e:\python352\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
# accuracy_test
y_test_predict = clf.predict(x_test)
print(metrics.accuracy_score(y_test,y_test_predict))

# %%
# probability output for future evaluation
y_test_predict = clf.predict_proba(x_test)
result = pd.DataFrame({'score':y_test_predict[:,1],'truth':y_test})
result.to_csv('./result/wb_lr_notime.csv')

# %%
# save model
model_name = 'wb_lr.pkl'
joblib.dump(clf,model_name)
