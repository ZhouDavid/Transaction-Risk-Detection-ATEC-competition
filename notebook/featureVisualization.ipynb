# %%
import pandas as pd

# %%
train_df = pd.read_csv('../data/full_size/atec_anti_fraud_train.csv')

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

# %%
for i in range(2,len(train_df.columns)):
#     res = train_df[cn].value_counts().sort_index()
#     x = np.array(res.index)
#     y = np.array(res)
    print(train_df.columns[i])
    try:
        plt.hist(train_df[train_df.columns[i]])
        plt.show()
    except:
        print('error, continue')
# Out:
# date
# f1
# f2
# f3
# f4
# f5
# error, continue
# f6
# f7
# f8
# f9
# f10
# f11
# f12
# f13
# f14
# f15
# f16
# f17
# f18
# f19
# f20
# error, continue
# f21
# error, continue
# f22
# error, continue
# f23
# error, continue
# f24
# error, continue
# f25
# error, continue
# f26
# error, continue
# f27
# error, continue
# f28
# error, continue
# f29
# error, continue
# f30
# error, continue
# f31
# error, continue
# f32
# error, continue
# f33
# error, continue
# f34
# error, continue
# f35
# error, continue
# f36
# error, continue
# f37
# error, continue
# f38
# error, continue
# f39
# error, continue
# f40
# error, continue
# f41
# error, continue
# f42
# error, continue
# f43
# error, continue
# f44
# error, continue
# f45
# error, continue
# f46
# error, continue
# f47
# error, continue
# f48
# error, continue
# f49
# error, continue
# f50
# error, continue
# f51
# error, continue
# f52
# error, continue
# f53
# error, continue
# f54
# error, continue
# f55
# error, continue
# f56
# ...

# %%
res = res.sort_index()
plt.plot(res)

# %%
import numpy as np
np.array(train_df['f1'].value_counts())[0]
# Out:
# 497410
