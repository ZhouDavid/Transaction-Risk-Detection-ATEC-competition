# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import svm
from sklearn.cross_validation import train_test_split
from sklearn import preprocessing
import xgboost as xgb
from sklearn import metrics

# %%
# divid date
import datetime
def date2weekday(date):
    date = str(date)
    year = int(date[0:4])
    month = int(date[4:6])
    day = int(date[6:])
    return datetime.datetime(year,month,day).weekday()

def ant_score(truth,score):
    FNR1 = 0.001
    FNR2 = 0.005
    FNR3 = 0.01
    min1 = min2 = min3 = 1
    for thr in np.arange(0,1+0.001,0.001):
        evaluate_table = pd.DataFrame({'truth':truth,'score':score})
        evaluate_table.loc[evaluate_table['score']>=thr,'score']=1
        evaluate_table.loc[evaluate_table['score']<thr,'score']=0
        TP = evaluate_table.loc[(evaluate_table['score']==1)&(evaluate_table['truth']==1)].shape[0]
        FN = evaluate_table.loc[(evaluate_table['score']==0)&(evaluate_table['truth']==1)].shape[0]
        TN = evaluate_table.loc[(evaluate_table['score']==0)&(evaluate_table['truth']==0)].shape[0]
        FP = evaluate_table.loc[(evaluate_table['score']==1)&(evaluate_table['truth']==0)].shape[0]
        TPR = TP/(TP+FN)
        FNR = FP/(TN+FP)
        if abs(FNR-FNR1)<min1:
            min1 = abs(FNR-FNR1)
            FNR11 = FNR
            TPR1 = TPR
        if abs(FNR-FNR2)<min2:
            min2 = abs(FNR-FNR2)
            FNR22 = FNR
            TPR2 = TPR
        if abs(FNR-FNR3)<min3:
            min3 = abs(FNR-FNR3)
            FNR33 = FNR
            TPR3 = TPR
    return 0.4*TPR1+0.3*TPR2+0.3*TPR3

# %%
# constant definition
full_data_path = '../data/full_size/atec_anti_fraud_train.csv'

# write sample data to file
df = pd.read_csv(full_data_path,index_col = 0)
df = df[df['label']!=-1] # drop no label
df = df.sort_values(by=['date']) # sort by date
df['day'] = df['date'].apply(lambda x:int(str(x)[6:]))
df['weekday'] =df['date'].apply(date2weekday)
df = df.drop(columns=['date'])

# %%
# train test split
X = df.iloc[:,1:]
Y = df.iloc[:,0]
train_ratio = 0.8
train_num = int(train_ratio*X.shape[0])
train_x = X.iloc[:train_num,:]
train_y = Y.iloc[:train_num]
test_x = X.iloc[train_num:,:]
test_y = Y.iloc[train_num:]

counts = train_y.value_counts()
neg_num = counts[0]
pos_num = counts[1]

# %%
from xgboost import XGBClassifier
xgb_500n9d01l = XGBClassifier(learning_rate=0.1,max_delt_step=1,calsample_bytree=0.8,
                                subsample=0.8,n_estimators=500,max_depth=9)
xgb_500n9d01l_list = []
from sklearn.model_selection import KFold
kf = KFold(n_splits=4,random_state=0,shuffle=True)

i = 1
predict_probas = [] # save each sub model's out scoring results
for train_index,test_index in kf.split(train_x):
    sub_train_x = train_x.iloc[train_index]
    sub_train_y = train_y.iloc[train_index]
    sub_test_x = train_x.iloc[test_index]
    sub_test_y = train_y.iloc[test_index]
    
    # training
    print('fitting model{}...'.format(i))
    xgb_500n9d01l.fit(sub_train_x,sub_train_y,eval_metric='error',verbose=True,
                      eval_set=[(test_x, test_y)],early_stopping_rounds=100)
    print('model{} predicting....'.format(i))
    sub_predict_y = xgb_500n9d01l.predict(sub_test_x)
    sub_predict_y_proba = xgb_500n9d01l.predict_proba(sub_test_x)[:,1]
    print('sub scoring....')
    print('precision: {}, recall: {}, ant_score: {}'.format(metrics.precision_score(sub_test_y,sub_predict_y),
                                                           metrics.recall_score(sub_test_y,sub_predict_y),
                                                           ant_score(sub_test_y,sub_predict_y_proba)))
    print('out scoring...')
    predict_y = xgb_500n9d01l.predict(test_x)
    predict_y_proba = xgb_500n9d01l.predict_proba(test_x)[:,1]
    print('precision: {}, recall: {}, ant_score: {}'.format(metrics.precision_score(test_y,predict_y),
                                                       metrics.recall_score(test_y,predict_y),
                                                       ant_score(test_y,predict_y_proba)))
    predict_probas.append(predict_y_proba)
    xgb_500n9d01l_list.append(xgb_500n9d01l)
    i+=1
# Out:
# fitting model1...
# [0]	validation_0-error:0.010924
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.010939
# [2]	validation_0-error:0.010747
# [3]	validation_0-error:0.010672
# [4]	validation_0-error:0.010742
# [5]	validation_0-error:0.010651
# [6]	validation_0-error:0.010555
# [7]	validation_0-error:0.010535
# [8]	validation_0-error:0.010454
# [9]	validation_0-error:0.01048
# [10]	validation_0-error:0.01048
# [11]	validation_0-error:0.010449
# [12]	validation_0-error:0.010439
# [13]	validation_0-error:0.010424
# [14]	validation_0-error:0.010409
# [15]	validation_0-error:0.010358
# [16]	validation_0-error:0.010374
# [17]	validation_0-error:0.010338
# [18]	validation_0-error:0.010313
# [19]	validation_0-error:0.010338
# [20]	validation_0-error:0.010303
# [21]	validation_0-error:0.010263
# [22]	validation_0-error:0.010288
# [23]	validation_0-error:0.010222
# [24]	validation_0-error:0.010207
# [25]	validation_0-error:0.010207
# [26]	validation_0-error:0.010222
# [27]	validation_0-error:0.010227
# [28]	validation_0-error:0.010202
# [29]	validation_0-error:0.010192
# [30]	validation_0-error:0.010141
# [31]	validation_0-error:0.010182
# [32]	validation_0-error:0.010116
# [33]	validation_0-error:0.010126
# [34]	validation_0-error:0.010081
# [35]	validation_0-error:0.010126
# [36]	validation_0-error:0.010055
# [37]	validation_0-error:0.010045
# [38]	validation_0-error:0.010066
# [39]	validation_0-error:0.00999
# [40]	validation_0-error:0.009939
# [41]	validation_0-error:0.00999
# [42]	validation_0-error:0.00999
# [43]	validation_0-error:0.009909
# [44]	validation_0-error:0.009879
# [45]	validation_0-error:0.009853
# [46]	validation_0-error:0.009864
# [47]	validation_0-error:0.009843
# [48]	validation_0-error:0.009874
# [49]	validation_0-error:0.009848
# [50]	validation_0-error:0.009884
# [51]	validation_0-error:0.009874
# [52]	validation_0-error:0.009879
# [53]	validation_0-error:0.009838
# [54]	validation_0-error:0.009894
# [55]	validation_0-error:0.009889
# [56]	validation_0-error:0.009899
# [57]	validation_0-error:0.009949
# [58]	validation_0-error:0.009894
# [59]	validation_0-error:0.009889
# [60]	validation_0-error:0.009904
# [61]	validation_0-error:0.009879
# [62]	validation_0-error:0.009874
# [63]	validation_0-error:0.009864
# [64]	validation_0-error:0.009899
# [65]	validation_0-error:0.009848
# [66]	validation_0-error:0.009813
# [67]	validation_0-error:0.009818
# [68]	validation_0-error:0.009828
# [69]	validation_0-error:0.009843
# [70]	validation_0-error:0.009828
# [71]	validation_0-error:0.009864
# [72]	validation_0-error:0.009838
# [73]	validation_0-error:0.009828
# [74]	validation_0-error:0.009808
# [75]	validation_0-error:0.009763
# [76]	validation_0-error:0.009768
# [77]	validation_0-error:0.009783
# [78]	validation_0-error:0.009803
# [79]	validation_0-error:0.009828
# [80]	validation_0-error:0.009813
# [81]	validation_0-error:0.009864
# [82]	validation_0-error:0.009843
# [83]	validation_0-error:0.009788
# [84]	validation_0-error:0.009823
# [85]	validation_0-error:0.009732
# [86]	validation_0-error:0.009732
# [87]	validation_0-error:0.009773
# [88]	validation_0-error:0.009778
# [89]	validation_0-error:0.009778
# [90]	validation_0-error:0.009803
# [91]	validation_0-error:0.009793
# [92]	validation_0-error:0.009783
# [93]	validation_0-error:0.009768
# [94]	validation_0-error:0.009737
# [95]	validation_0-error:0.009742
# [96]	validation_0-error:0.009773
# [97]	validation_0-error:0.009747
# [98]	validation_0-error:0.009788
# [99]	validation_0-error:0.009788
# [100]	validation_0-error:0.009722
# [101]	validation_0-error:0.009702
# [102]	validation_0-error:0.009727
# [103]	validation_0-error:0.009752
# [104]	validation_0-error:0.009747
# [105]	validation_0-error:0.009722
# [106]	validation_0-error:0.009677
# [107]	validation_0-error:0.009707
# [108]	validation_0-error:0.009677
# [109]	validation_0-error:0.009677
# [110]	validation_0-error:0.009692
# [111]	validation_0-error:0.009712
# [112]	validation_0-error:0.009712
# [113]	validation_0-error:0.009687
# [114]	validation_0-error:0.009712
# [115]	validation_0-error:0.009712
# [116]	validation_0-error:0.009697
# [117]	validation_0-error:0.009682
# [118]	validation_0-error:0.009687
# [119]	validation_0-error:0.009692
# [120]	validation_0-error:0.009682
# [121]	validation_0-error:0.009677
# [122]	validation_0-error:0.009687
# [123]	validation_0-error:0.009687
# [124]	validation_0-error:0.009702
# [125]	validation_0-error:0.009717
# [126]	validation_0-error:0.009742
# [127]	validation_0-error:0.009742
# [128]	validation_0-error:0.009768
# [129]	validation_0-error:0.009752
# [130]	validation_0-error:0.009742
# [131]	validation_0-error:0.009803
# [132]	validation_0-error:0.009798
# [133]	validation_0-error:0.009803
# [134]	validation_0-error:0.009788
# [135]	validation_0-error:0.009798
# [136]	validation_0-error:0.009773
# [137]	validation_0-error:0.009773
# [138]	validation_0-error:0.009833
# [139]	validation_0-error:0.009813
# [140]	validation_0-error:0.009828
# [141]	validation_0-error:0.009838
# [142]	validation_0-error:0.009843
# [143]	validation_0-error:0.009869
# [144]	validation_0-error:0.009899
# [145]	validation_0-error:0.009944
# [146]	validation_0-error:0.009934
# [147]	validation_0-error:0.009949
# [148]	validation_0-error:0.009954
# [149]	validation_0-error:0.009959
# [150]	validation_0-error:0.009949
# [151]	validation_0-error:0.009954
# [152]	validation_0-error:0.009954
# [153]	validation_0-error:0.009965
# [154]	validation_0-error:0.009949
# [155]	validation_0-error:0.009975
# [156]	validation_0-error:0.009949
# [157]	validation_0-error:0.009929
# [158]	validation_0-error:0.009909
# [159]	validation_0-error:0.009934
# [160]	validation_0-error:0.009899
# [161]	validation_0-error:0.009904
# [162]	validation_0-error:0.009909
# [163]	validation_0-error:0.009929
# [164]	validation_0-error:0.009914
# [165]	validation_0-error:0.009884
# [166]	validation_0-error:0.009823
# [167]	validation_0-error:0.009838
# [168]	validation_0-error:0.009838
# [169]	validation_0-error:0.009798
# [170]	validation_0-error:0.009823
# [171]	validation_0-error:0.009864
# [172]	validation_0-error:0.009864
# [173]	validation_0-error:0.009864
# [174]	validation_0-error:0.009858
# [175]	validation_0-error:0.009904
# [176]	validation_0-error:0.009884
# [177]	validation_0-error:0.009853
# [178]	validation_0-error:0.009853
# [179]	validation_0-error:0.009848
# [180]	validation_0-error:0.009858
# [181]	validation_0-error:0.009879
# [182]	validation_0-error:0.009874
# [183]	validation_0-error:0.009864
# [184]	validation_0-error:0.009838
# [185]	validation_0-error:0.009879
# [186]	validation_0-error:0.009879
# [187]	validation_0-error:0.009869
# [188]	validation_0-error:0.009838
# [189]	validation_0-error:0.009838
# [190]	validation_0-error:0.009823
# [191]	validation_0-error:0.009838
# [192]	validation_0-error:0.009848
# [193]	validation_0-error:0.009848
# [194]	validation_0-error:0.009853
# [195]	validation_0-error:0.009853
# [196]	validation_0-error:0.009889
# [197]	validation_0-error:0.009899
# [198]	validation_0-error:0.009894
# [199]	validation_0-error:0.009929
# [200]	validation_0-error:0.009924
# [201]	validation_0-error:0.009944
# [202]	validation_0-error:0.009965
# [203]	validation_0-error:0.00998
# [204]	validation_0-error:0.009954
# [205]	validation_0-error:0.009919
# [206]	validation_0-error:0.009939
# Stopping. Best iteration:
# [106]	validation_0-error:0.009677
#
# model1 predicting....
# d:\python35\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# sub scoring....
# precision: 0.8147321428571429, recall: 0.611646418098031, ant_score: 0.7030582320904901
# out scoring...
# d:\python35\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# precision: 0.6926658905704307, recall: 0.4524714828897338, ant_score: 0.5042585551330798
# fitting model2...
# [0]	validation_0-error:0.011242
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.011172
# [2]	validation_0-error:0.01103
# [3]	validation_0-error:0.010752
# [4]	validation_0-error:0.010667
# [5]	validation_0-error:0.010768
# [6]	validation_0-error:0.010737
# [7]	validation_0-error:0.010732
# [8]	validation_0-error:0.010712
# [9]	validation_0-error:0.010667
# [10]	validation_0-error:0.010656
# [11]	validation_0-error:0.010591
# [12]	validation_0-error:0.010611
# [13]	validation_0-error:0.010581
# [14]	validation_0-error:0.010601
# [15]	validation_0-error:0.010586
# [16]	validation_0-error:0.010566
# [17]	validation_0-error:0.010545
# [18]	validation_0-error:0.010545
# [19]	validation_0-error:0.010485
# [20]	validation_0-error:0.010439
# [21]	validation_0-error:0.010454
# [22]	validation_0-error:0.010459
# [23]	validation_0-error:0.010444
# [24]	validation_0-error:0.010475
# [25]	validation_0-error:0.01047
# [26]	validation_0-error:0.010475
# [27]	validation_0-error:0.0105
# [28]	validation_0-error:0.010434
# [29]	validation_0-error:0.010444
# [30]	validation_0-error:0.010399
# [31]	validation_0-error:0.010434
# [32]	validation_0-error:0.010414
# [33]	validation_0-error:0.010364
# [34]	validation_0-error:0.010358
# [35]	validation_0-error:0.010278
# [36]	validation_0-error:0.010273
# [37]	validation_0-error:0.010328
# [38]	validation_0-error:0.010343
# [39]	validation_0-error:0.010303
# [40]	validation_0-error:0.010263
# [41]	validation_0-error:0.010162
# [42]	validation_0-error:0.010106
# [43]	validation_0-error:0.010131
# [44]	validation_0-error:0.010146
# [45]	validation_0-error:0.010111
# [46]	validation_0-error:0.010116
# [47]	validation_0-error:0.010136
# [48]	validation_0-error:0.010101
# [49]	validation_0-error:0.010096
# [50]	validation_0-error:0.010126
# [51]	validation_0-error:0.010086
# [52]	validation_0-error:0.010081
# [53]	validation_0-error:0.010101
# [54]	validation_0-error:0.010146
# [55]	validation_0-error:0.010106
# [56]	validation_0-error:0.010101
# [57]	validation_0-error:0.010111
# [58]	validation_0-error:0.010126
# [59]	validation_0-error:0.010141
# [60]	validation_0-error:0.010136
# [61]	validation_0-error:0.010146
# [62]	validation_0-error:0.010136
# [63]	validation_0-error:0.010091
# [64]	validation_0-error:0.010076
# [65]	validation_0-error:0.010066
# [66]	validation_0-error:0.010076
# [67]	validation_0-error:0.010061
# [68]	validation_0-error:0.010086
# [69]	validation_0-error:0.010101
# [70]	validation_0-error:0.010116
# [71]	validation_0-error:0.01005
# [72]	validation_0-error:0.01005
# [73]	validation_0-error:0.010045
# [74]	validation_0-error:0.010081
# [75]	validation_0-error:0.010081
# [76]	validation_0-error:0.010096
# [77]	validation_0-error:0.010081
# [78]	validation_0-error:0.010061
# [79]	validation_0-error:0.010106
# [80]	validation_0-error:0.010035
# [81]	validation_0-error:0.010061
# [82]	validation_0-error:0.010066
# [83]	validation_0-error:0.010045
# [84]	validation_0-error:0.010045
# [85]	validation_0-error:0.010106
# [86]	validation_0-error:0.010086
# [87]	validation_0-error:0.010086
# [88]	validation_0-error:0.010071
# [89]	validation_0-error:0.010071
# [90]	validation_0-error:0.010081
# [91]	validation_0-error:0.010096
# [92]	validation_0-error:0.010091
# [93]	validation_0-error:0.010071
# [94]	validation_0-error:0.01004
# [95]	validation_0-error:0.010005
# [96]	validation_0-error:0.010096
# [97]	validation_0-error:0.010066
# [98]	validation_0-error:0.010045
# [99]	validation_0-error:0.01004
# [100]	validation_0-error:0.010005
# [101]	validation_0-error:0.010025
# [102]	validation_0-error:0.01005
# [103]	validation_0-error:0.010055
# [104]	validation_0-error:0.010061
# [105]	validation_0-error:0.01002
# [106]	validation_0-error:0.01001
# [107]	validation_0-error:0.010035
# [108]	validation_0-error:0.010035
# [109]	validation_0-error:0.01004
# [110]	validation_0-error:0.010045
# [111]	validation_0-error:0.010066
# [112]	validation_0-error:0.01003
# [113]	validation_0-error:0.01004
# [114]	validation_0-error:0.010061
# [115]	validation_0-error:0.01005
# [116]	validation_0-error:0.01002
# [117]	validation_0-error:0.01001
# [118]	validation_0-error:0.010015
# [119]	validation_0-error:0.009985
# [120]	validation_0-error:0.01001
# [121]	validation_0-error:0.01
# [122]	validation_0-error:0.009949
# [123]	validation_0-error:0.009889
# [124]	validation_0-error:0.009965
# [125]	validation_0-error:0.009965
# [126]	validation_0-error:0.009995
# [127]	validation_0-error:0.009985
# [128]	validation_0-error:0.009944
# [129]	validation_0-error:0.009894
# [130]	validation_0-error:0.009914
# [131]	validation_0-error:0.009944
# [132]	validation_0-error:0.009924
# [133]	validation_0-error:0.009904
# [134]	validation_0-error:0.009909
# [135]	validation_0-error:0.009959
# [136]	validation_0-error:0.009934
# [137]	validation_0-error:0.009934
# [138]	validation_0-error:0.009959
# [139]	validation_0-error:0.009944
# [140]	validation_0-error:0.009934
# [141]	validation_0-error:0.00997
# [142]	validation_0-error:0.00998
# [143]	validation_0-error:0.009954
# [144]	validation_0-error:0.009959
# [145]	validation_0-error:0.00998
# [146]	validation_0-error:0.00999
# [147]	validation_0-error:0.009944
# [148]	validation_0-error:0.009929
# [149]	validation_0-error:0.009909
# [150]	validation_0-error:0.009919
# [151]	validation_0-error:0.009934
# [152]	validation_0-error:0.009919
# [153]	validation_0-error:0.009924
# [154]	validation_0-error:0.009924
# [155]	validation_0-error:0.009919
# [156]	validation_0-error:0.009939
# [157]	validation_0-error:0.009939
# [158]	validation_0-error:0.009929
# [159]	validation_0-error:0.009929
# [160]	validation_0-error:0.009899
# [161]	validation_0-error:0.009879
# [162]	validation_0-error:0.009879
# [163]	validation_0-error:0.009879
# [164]	validation_0-error:0.009909
# [165]	validation_0-error:0.009904
# [166]	validation_0-error:0.009894
# [167]	validation_0-error:0.009914
# [168]	validation_0-error:0.009884
# [169]	validation_0-error:0.009884
# [170]	validation_0-error:0.009884
# [171]	validation_0-error:0.009889
# [172]	validation_0-error:0.009818
# [173]	validation_0-error:0.009843
# [174]	validation_0-error:0.009879
# [175]	validation_0-error:0.009914
# [176]	validation_0-error:0.009884
# [177]	validation_0-error:0.009889
# [178]	validation_0-error:0.009909
# [179]	validation_0-error:0.009934
# [180]	validation_0-error:0.009909
# [181]	validation_0-error:0.009924
# [182]	validation_0-error:0.009929
# [183]	validation_0-error:0.009924
# [184]	validation_0-error:0.009909
# [185]	validation_0-error:0.009904
# [186]	validation_0-error:0.009965
# [187]	validation_0-error:0.009944
# [188]	validation_0-error:0.009914
# [189]	validation_0-error:0.009934
# [190]	validation_0-error:0.009929
# [191]	validation_0-error:0.009904
# [192]	validation_0-error:0.009909
# [193]	validation_0-error:0.009934
# [194]	validation_0-error:0.009909
# [195]	validation_0-error:0.009929
# [196]	validation_0-error:0.009939
# [197]	validation_0-error:0.009965
# [198]	validation_0-error:0.009949
# [199]	validation_0-error:0.009899
# [200]	validation_0-error:0.009894
# [201]	validation_0-error:0.009909
# [202]	validation_0-error:0.009899
# [203]	validation_0-error:0.009899
# [204]	validation_0-error:0.009889
# [205]	validation_0-error:0.009904
# [206]	validation_0-error:0.009894
# [207]	validation_0-error:0.009924
# [208]	validation_0-error:0.009884
# [209]	validation_0-error:0.009884
# [210]	validation_0-error:0.009914
# [211]	validation_0-error:0.009914
# [212]	validation_0-error:0.009899
# [213]	validation_0-error:0.009884
# [214]	validation_0-error:0.009879
# [215]	validation_0-error:0.009884
# [216]	validation_0-error:0.009858
# [217]	validation_0-error:0.009874
# [218]	validation_0-error:0.009848
# [219]	validation_0-error:0.009823
# [220]	validation_0-error:0.009838
# [221]	validation_0-error:0.009838
# [222]	validation_0-error:0.009828
# [223]	validation_0-error:0.009833
# [224]	validation_0-error:0.009858
# [225]	validation_0-error:0.009889
# [226]	validation_0-error:0.009919
# [227]	validation_0-error:0.009939
# [228]	validation_0-error:0.009965
# [229]	validation_0-error:0.009965
# [230]	validation_0-error:0.009944
# [231]	validation_0-error:0.009939
# [232]	validation_0-error:0.009965
# [233]	validation_0-error:0.009985
# [234]	validation_0-error:0.009965
# [235]	validation_0-error:0.009929
# [236]	validation_0-error:0.009904
# [237]	validation_0-error:0.009864
# [238]	validation_0-error:0.009889
# [239]	validation_0-error:0.009914
# [240]	validation_0-error:0.009884
# [241]	validation_0-error:0.009874
# [242]	validation_0-error:0.009889
# [243]	validation_0-error:0.009879
# [244]	validation_0-error:0.009909
# [245]	validation_0-error:0.009909
# [246]	validation_0-error:0.009914
# [247]	validation_0-error:0.009959
# [248]	validation_0-error:0.009959
# [249]	validation_0-error:0.009944
# [250]	validation_0-error:0.009965
# [251]	validation_0-error:0.009959
# [252]	validation_0-error:0.009944
# [253]	validation_0-error:0.009954
# [254]	validation_0-error:0.009939
# [255]	validation_0-error:0.009975
# [256]	validation_0-error:0.009995
# [257]	validation_0-error:0.009949
# [258]	validation_0-error:0.009975
# [259]	validation_0-error:0.00997
# [260]	validation_0-error:0.009954
# [261]	validation_0-error:0.009965
# [262]	validation_0-error:0.00997
# [263]	validation_0-error:0.009985
# [264]	validation_0-error:0.00998
# [265]	validation_0-error:0.009995
# [266]	validation_0-error:0.009965
# [267]	validation_0-error:0.009965
# [268]	validation_0-error:0.009975
# [269]	validation_0-error:0.009965
# [270]	validation_0-error:0.01001
# [271]	validation_0-error:0.01002
# [272]	validation_0-error:0.009995
# Stopping. Best iteration:
# [172]	validation_0-error:0.009818
#
# model2 predicting....
# d:\python35\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# sub scoring....
# precision: 0.8067928730512249, recall: 0.6192307692307693, ant_score: 0.6918376068376068
# out scoring...
# d:\python35\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# precision: 0.6795366795366795, recall: 0.46844106463878327, ant_score: 0.49885931558935365
# fitting model3...
# [0]	validation_0-error:0.011146
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.010909
# [2]	validation_0-error:0.010717
# [3]	validation_0-error:0.010631
# [4]	validation_0-error:0.010611
# [5]	validation_0-error:0.01055
# [6]	validation_0-error:0.010545
# [7]	validation_0-error:0.010495
# [8]	validation_0-error:0.0105
# [9]	validation_0-error:0.010459
# [10]	validation_0-error:0.010384
# [11]	validation_0-error:0.010384
# [12]	validation_0-error:0.010374
# [13]	validation_0-error:0.010439
# [14]	validation_0-error:0.010384
# [15]	validation_0-error:0.010419
# [16]	validation_0-error:0.010414
# [17]	validation_0-error:0.010364
# [18]	validation_0-error:0.010293
# [19]	validation_0-error:0.010283
# [20]	validation_0-error:0.010263
# [21]	validation_0-error:0.010338
# [22]	validation_0-error:0.010303
# [23]	validation_0-error:0.010293
# [24]	validation_0-error:0.010288
# [25]	validation_0-error:0.010207
# [26]	validation_0-error:0.010247
# [27]	validation_0-error:0.010182
# [28]	validation_0-error:0.010151
# [29]	validation_0-error:0.010182
# [30]	validation_0-error:0.010126
# [31]	validation_0-error:0.010126
# [32]	validation_0-error:0.010106
# [33]	validation_0-error:0.010106
# [34]	validation_0-error:0.010091
# [35]	validation_0-error:0.010121
# [36]	validation_0-error:0.010126
# [37]	validation_0-error:0.010156
# [38]	validation_0-error:0.010045
# [39]	validation_0-error:0.01004
# [40]	validation_0-error:0.010066
# [41]	validation_0-error:0.010045
# [42]	validation_0-error:0.010025
# [43]	validation_0-error:0.009985
# [44]	validation_0-error:0.010015
# [45]	validation_0-error:0.01002
# [46]	validation_0-error:0.00997
# [47]	validation_0-error:0.009954
# [48]	validation_0-error:0.00998
# [49]	validation_0-error:0.009944
# [50]	validation_0-error:0.009924
# [51]	validation_0-error:0.009909
# [52]	validation_0-error:0.009884
# [53]	validation_0-error:0.009899
# [54]	validation_0-error:0.009869
# [55]	validation_0-error:0.009869
# [56]	validation_0-error:0.009879
# [57]	validation_0-error:0.009894
# [58]	validation_0-error:0.009869
# [59]	validation_0-error:0.009884
# [60]	validation_0-error:0.009904
# [61]	validation_0-error:0.009894
# [62]	validation_0-error:0.009894
# [63]	validation_0-error:0.009858
# [64]	validation_0-error:0.009869
# [65]	validation_0-error:0.009828
# [66]	validation_0-error:0.009783
# [67]	validation_0-error:0.009773
# [68]	validation_0-error:0.009793
# [69]	validation_0-error:0.009803
# [70]	validation_0-error:0.009813
# [71]	validation_0-error:0.009843
# [72]	validation_0-error:0.009853
# [73]	validation_0-error:0.009838
# [74]	validation_0-error:0.009828
# [75]	validation_0-error:0.009813
# [76]	validation_0-error:0.009828
# [77]	validation_0-error:0.009823
# [78]	validation_0-error:0.009788
# [79]	validation_0-error:0.009732
# [80]	validation_0-error:0.009778
# [81]	validation_0-error:0.009747
# [82]	validation_0-error:0.009752
# [83]	validation_0-error:0.009793
# [84]	validation_0-error:0.009788
# [85]	validation_0-error:0.009773
# [86]	validation_0-error:0.009737
# [87]	validation_0-error:0.009773
# [88]	validation_0-error:0.009752
# [89]	validation_0-error:0.009742
# [90]	validation_0-error:0.009803
# [91]	validation_0-error:0.009843
# [92]	validation_0-error:0.009848
# [93]	validation_0-error:0.009853
# [94]	validation_0-error:0.009828
# [95]	validation_0-error:0.009798
# [96]	validation_0-error:0.009773
# [97]	validation_0-error:0.009783
# [98]	validation_0-error:0.009788
# [99]	validation_0-error:0.009773
# [100]	validation_0-error:0.009747
# [101]	validation_0-error:0.009742
# [102]	validation_0-error:0.009803
# [103]	validation_0-error:0.009757
# [104]	validation_0-error:0.009727
# [105]	validation_0-error:0.009737
# [106]	validation_0-error:0.009773
# [107]	validation_0-error:0.009768
# [108]	validation_0-error:0.009768
# [109]	validation_0-error:0.009722
# [110]	validation_0-error:0.009732
# [111]	validation_0-error:0.009737
# [112]	validation_0-error:0.009747
# [113]	validation_0-error:0.009757
# [114]	validation_0-error:0.009763
# [115]	validation_0-error:0.009697
# [116]	validation_0-error:0.009656
# [117]	validation_0-error:0.009687
# [118]	validation_0-error:0.009692
# [119]	validation_0-error:0.009667
# [120]	validation_0-error:0.009641
# [121]	validation_0-error:0.009646
# [122]	validation_0-error:0.009672
# [123]	validation_0-error:0.009682
# [124]	validation_0-error:0.009717
# [125]	validation_0-error:0.009667
# [126]	validation_0-error:0.009641
# [127]	validation_0-error:0.009677
# [128]	validation_0-error:0.009656
# [129]	validation_0-error:0.009662
# [130]	validation_0-error:0.009667
# [131]	validation_0-error:0.009672
# [132]	validation_0-error:0.009672
# [133]	validation_0-error:0.009667
# [134]	validation_0-error:0.009672
# [135]	validation_0-error:0.009656
# [136]	validation_0-error:0.009656
# [137]	validation_0-error:0.009651
# [138]	validation_0-error:0.009651
# [139]	validation_0-error:0.009692
# [140]	validation_0-error:0.009747
# [141]	validation_0-error:0.009732
# [142]	validation_0-error:0.009747
# [143]	validation_0-error:0.009712
# [144]	validation_0-error:0.009702
# [145]	validation_0-error:0.009687
# [146]	validation_0-error:0.009692
# [147]	validation_0-error:0.009702
# [148]	validation_0-error:0.009712
# [149]	validation_0-error:0.009712
# [150]	validation_0-error:0.009712
# [151]	validation_0-error:0.009707
# [152]	validation_0-error:0.009707
# [153]	validation_0-error:0.009727
# [154]	validation_0-error:0.009722
# [155]	validation_0-error:0.009717
# [156]	validation_0-error:0.009692
# [157]	validation_0-error:0.009692
# [158]	validation_0-error:0.009697
# [159]	validation_0-error:0.009707
# [160]	validation_0-error:0.009712
# [161]	validation_0-error:0.009662
# [162]	validation_0-error:0.009667
# [163]	validation_0-error:0.009697
# [164]	validation_0-error:0.009677
# [165]	validation_0-error:0.009677
# [166]	validation_0-error:0.009697
# [167]	validation_0-error:0.009662
# [168]	validation_0-error:0.009662
# [169]	validation_0-error:0.009662
# [170]	validation_0-error:0.009682
# [171]	validation_0-error:0.009682
# [172]	validation_0-error:0.009656
# [173]	validation_0-error:0.009641
# [174]	validation_0-error:0.009651
# [175]	validation_0-error:0.009692
# [176]	validation_0-error:0.009672
# [177]	validation_0-error:0.009667
# [178]	validation_0-error:0.009702
# [179]	validation_0-error:0.009697
# [180]	validation_0-error:0.009682
# [181]	validation_0-error:0.009702
# [182]	validation_0-error:0.009702
# [183]	validation_0-error:0.009697
# [184]	validation_0-error:0.009717
# [185]	validation_0-error:0.009732
# [186]	validation_0-error:0.009692
# [187]	validation_0-error:0.009732
# [188]	validation_0-error:0.009798
# [189]	validation_0-error:0.009793
# [190]	validation_0-error:0.009757
# [191]	validation_0-error:0.009747
# [192]	validation_0-error:0.009757
# [193]	validation_0-error:0.009763
# [194]	validation_0-error:0.009732
# [195]	validation_0-error:0.009763
# [196]	validation_0-error:0.009763
# [197]	validation_0-error:0.009752
# [198]	validation_0-error:0.009773
# [199]	validation_0-error:0.009803
# [200]	validation_0-error:0.009737
# [201]	validation_0-error:0.009747
# [202]	validation_0-error:0.009732
# [203]	validation_0-error:0.009773
# [204]	validation_0-error:0.009702
# [205]	validation_0-error:0.009662
# [206]	validation_0-error:0.009636
# [207]	validation_0-error:0.009646
# [208]	validation_0-error:0.009636
# [209]	validation_0-error:0.009667
# [210]	validation_0-error:0.009672
# [211]	validation_0-error:0.009662
# [212]	validation_0-error:0.009692
# [213]	validation_0-error:0.009717
# [214]	validation_0-error:0.009712
# [215]	validation_0-error:0.009702
# [216]	validation_0-error:0.009717
# [217]	validation_0-error:0.009742
# [218]	validation_0-error:0.009763
# [219]	validation_0-error:0.009742
# [220]	validation_0-error:0.009742
# [221]	validation_0-error:0.009757
# [222]	validation_0-error:0.009768
# [223]	validation_0-error:0.009783
# [224]	validation_0-error:0.009763
# [225]	validation_0-error:0.009768
# [226]	validation_0-error:0.009768
# [227]	validation_0-error:0.009773
# [228]	validation_0-error:0.009763
# [229]	validation_0-error:0.009768
# [230]	validation_0-error:0.009773
# [231]	validation_0-error:0.009722
# [232]	validation_0-error:0.009727
# [233]	validation_0-error:0.009747
# [234]	validation_0-error:0.009747
# [235]	validation_0-error:0.009783
# [236]	validation_0-error:0.009803
# [237]	validation_0-error:0.009778
# [238]	validation_0-error:0.009763
# [239]	validation_0-error:0.009763
# [240]	validation_0-error:0.009773
# [241]	validation_0-error:0.009773
# [242]	validation_0-error:0.009813
# [243]	validation_0-error:0.009778
# [244]	validation_0-error:0.009757
# [245]	validation_0-error:0.009747
# [246]	validation_0-error:0.009737
# [247]	validation_0-error:0.009727
# [248]	validation_0-error:0.009763
# [249]	validation_0-error:0.009773
# [250]	validation_0-error:0.009798
# [251]	validation_0-error:0.009823
# [252]	validation_0-error:0.009747
# [253]	validation_0-error:0.009778
# [254]	validation_0-error:0.009768
# [255]	validation_0-error:0.009763
# [256]	validation_0-error:0.009783
# [257]	validation_0-error:0.009788
# [258]	validation_0-error:0.009768
# [259]	validation_0-error:0.009763
# [260]	validation_0-error:0.009757
# [261]	validation_0-error:0.009742
# [262]	validation_0-error:0.009757
# [263]	validation_0-error:0.009768
# [264]	validation_0-error:0.009783
# [265]	validation_0-error:0.009803
# [266]	validation_0-error:0.009783
# [267]	validation_0-error:0.009783
# [268]	validation_0-error:0.009793
# [269]	validation_0-error:0.009778
# [270]	validation_0-error:0.009773
# [271]	validation_0-error:0.009778
# [272]	validation_0-error:0.009763
# [273]	validation_0-error:0.009757
# [274]	validation_0-error:0.009763
# [275]	validation_0-error:0.009747
# [276]	validation_0-error:0.009757
# [277]	validation_0-error:0.009742
# [278]	validation_0-error:0.009757
# [279]	validation_0-error:0.009752
# [280]	validation_0-error:0.009763
# [281]	validation_0-error:0.009737
# [282]	validation_0-error:0.009747
# [283]	validation_0-error:0.009752
# [284]	validation_0-error:0.009783
# [285]	validation_0-error:0.009783
# [286]	validation_0-error:0.009773
# [287]	validation_0-error:0.009768
# [288]	validation_0-error:0.009773
# [289]	validation_0-error:0.009773
# [290]	validation_0-error:0.009773
# [291]	validation_0-error:0.009747
# [292]	validation_0-error:0.009742
# [293]	validation_0-error:0.009712
# [294]	validation_0-error:0.009712
# [295]	validation_0-error:0.009747
# [296]	validation_0-error:0.009732
# [297]	validation_0-error:0.009742
# [298]	validation_0-error:0.009732
# [299]	validation_0-error:0.009742
# [300]	validation_0-error:0.009732
# [301]	validation_0-error:0.009727
# [302]	validation_0-error:0.009712
# [303]	validation_0-error:0.009712
# [304]	validation_0-error:0.009727
# [305]	validation_0-error:0.009727
# [306]	validation_0-error:0.009742
# Stopping. Best iteration:
# [206]	validation_0-error:0.009636
#
# model3 predicting....
# d:\python35\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# sub scoring....
# precision: 0.806573275862069, recall: 0.6209041891331398, ant_score: 0.6976358357527996
# out scoring...
# d:\python35\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# precision: 0.6843766438716465, recall: 0.49467680608365017, ant_score: 0.5075285171102661
# fitting model4...
# [0]	validation_0-error:0.011192
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.011035
# [2]	validation_0-error:0.010995
# [3]	validation_0-error:0.010929
# [4]	validation_0-error:0.010813
# [5]	validation_0-error:0.010707
# [6]	validation_0-error:0.010571
# [7]	validation_0-error:0.010626
# [8]	validation_0-error:0.010545
# [9]	validation_0-error:0.010495
# [10]	validation_0-error:0.01049
# [11]	validation_0-error:0.01047
# [12]	validation_0-error:0.010495
# [13]	validation_0-error:0.010525
# [14]	validation_0-error:0.010475
# [15]	validation_0-error:0.010348
# [16]	validation_0-error:0.010348
# [17]	validation_0-error:0.010364
# [18]	validation_0-error:0.010328
# [19]	validation_0-error:0.010323
# [20]	validation_0-error:0.010318
# [21]	validation_0-error:0.010303
# [22]	validation_0-error:0.010278
# [23]	validation_0-error:0.010278
# [24]	validation_0-error:0.010232
# [25]	validation_0-error:0.010242
# [26]	validation_0-error:0.010222
# [27]	validation_0-error:0.010212
# [28]	validation_0-error:0.010192
# [29]	validation_0-error:0.010167
# [30]	validation_0-error:0.010172
# [31]	validation_0-error:0.010131
# [32]	validation_0-error:0.010116
# [33]	validation_0-error:0.010121
# [34]	validation_0-error:0.010066
# [35]	validation_0-error:0.010025
# [36]	validation_0-error:0.01005
# [37]	validation_0-error:0.010081
# [38]	validation_0-error:0.010086
# [39]	validation_0-error:0.010035
# [40]	validation_0-error:0.010081
# [41]	validation_0-error:0.010086
# [42]	validation_0-error:0.010015
# [43]	validation_0-error:0.01003
# [44]	validation_0-error:0.01003
# [45]	validation_0-error:0.01
# [46]	validation_0-error:0.01002
# [47]	validation_0-error:0.010066
# [48]	validation_0-error:0.010071
# [49]	validation_0-error:0.01005
# [50]	validation_0-error:0.010055
# [51]	validation_0-error:0.010045
# [52]	validation_0-error:0.010055
# [53]	validation_0-error:0.010071
# [54]	validation_0-error:0.010055
# [55]	validation_0-error:0.010055
# [56]	validation_0-error:0.01003
# [57]	validation_0-error:0.010045
# [58]	validation_0-error:0.01001
# [59]	validation_0-error:0.010061
# [60]	validation_0-error:0.010061
# [61]	validation_0-error:0.010061
# [62]	validation_0-error:0.010076
# [63]	validation_0-error:0.010005
# [64]	validation_0-error:0.010035
# [65]	validation_0-error:0.010025
# [66]	validation_0-error:0.009965
# [67]	validation_0-error:0.009934
# [68]	validation_0-error:0.009924
# [69]	validation_0-error:0.009909
# [70]	validation_0-error:0.009924
# [71]	validation_0-error:0.009909
# [72]	validation_0-error:0.009899
# [73]	validation_0-error:0.009909
# [74]	validation_0-error:0.009919
# [75]	validation_0-error:0.009853
# [76]	validation_0-error:0.009848
# [77]	validation_0-error:0.009848
# [78]	validation_0-error:0.009858
# [79]	validation_0-error:0.009853
# [80]	validation_0-error:0.009869
# [81]	validation_0-error:0.009924
# [82]	validation_0-error:0.009899
# [83]	validation_0-error:0.009858
# [84]	validation_0-error:0.009884
# [85]	validation_0-error:0.009884
# [86]	validation_0-error:0.009924
# [87]	validation_0-error:0.00998
# [88]	validation_0-error:0.009939
# [89]	validation_0-error:0.009965
# [90]	validation_0-error:0.009939
# [91]	validation_0-error:0.009975
# [92]	validation_0-error:0.009954
# [93]	validation_0-error:0.009939
# [94]	validation_0-error:0.009909
# [95]	validation_0-error:0.009909
# [96]	validation_0-error:0.009904
# [97]	validation_0-error:0.009904
# [98]	validation_0-error:0.009818
# [99]	validation_0-error:0.009763
# [100]	validation_0-error:0.009783
# [101]	validation_0-error:0.009823
# [102]	validation_0-error:0.009843
# [103]	validation_0-error:0.009843
# [104]	validation_0-error:0.009843
# [105]	validation_0-error:0.009828
# [106]	validation_0-error:0.009833
# [107]	validation_0-error:0.009843
# [108]	validation_0-error:0.009864
# [109]	validation_0-error:0.009838
# [110]	validation_0-error:0.009823
# [111]	validation_0-error:0.009808
# [112]	validation_0-error:0.009818
# [113]	validation_0-error:0.009889
# [114]	validation_0-error:0.009919
# [115]	validation_0-error:0.009879
# [116]	validation_0-error:0.009869
# [117]	validation_0-error:0.009853
# [118]	validation_0-error:0.009858
# [119]	validation_0-error:0.009864
# [120]	validation_0-error:0.009879
# [121]	validation_0-error:0.009914
# [122]	validation_0-error:0.009909
# [123]	validation_0-error:0.009949
# [124]	validation_0-error:0.009924
# [125]	validation_0-error:0.009939
# [126]	validation_0-error:0.009949
# [127]	validation_0-error:0.009944
# [128]	validation_0-error:0.009939
# [129]	validation_0-error:0.009954
# [130]	validation_0-error:0.00997
# [131]	validation_0-error:0.009934
# [132]	validation_0-error:0.009909
# [133]	validation_0-error:0.009914
# [134]	validation_0-error:0.009944
# [135]	validation_0-error:0.009965
# [136]	validation_0-error:0.00999
# [137]	validation_0-error:0.010015
# [138]	validation_0-error:0.01001
# [139]	validation_0-error:0.01002
# [140]	validation_0-error:0.010005
# [141]	validation_0-error:0.009995
# [142]	validation_0-error:0.010015
# [143]	validation_0-error:0.01001
# [144]	validation_0-error:0.010015
# [145]	validation_0-error:0.010015
# [146]	validation_0-error:0.01003
# [147]	validation_0-error:0.010071
# [148]	validation_0-error:0.010005
# [149]	validation_0-error:0.01
# [150]	validation_0-error:0.00998
# [151]	validation_0-error:0.01
# [152]	validation_0-error:0.010015
# [153]	validation_0-error:0.009975
# [154]	validation_0-error:0.009975
# [155]	validation_0-error:0.009959
# [156]	validation_0-error:0.009985
# [157]	validation_0-error:0.009944
# [158]	validation_0-error:0.00999
# [159]	validation_0-error:0.010005
# [160]	validation_0-error:0.010005
# [161]	validation_0-error:0.01005
# [162]	validation_0-error:0.010066
# [163]	validation_0-error:0.010055
# [164]	validation_0-error:0.010061
# [165]	validation_0-error:0.010071
# [166]	validation_0-error:0.010066
# [167]	validation_0-error:0.010071
# [168]	validation_0-error:0.010096
# [169]	validation_0-error:0.010086
# [170]	validation_0-error:0.010066
# [171]	validation_0-error:0.010045
# [172]	validation_0-error:0.010035
# [173]	validation_0-error:0.010076
# [174]	validation_0-error:0.010025
# [175]	validation_0-error:0.01004
# [176]	validation_0-error:0.010066
# [177]	validation_0-error:0.010061
# [178]	validation_0-error:0.010061
# [179]	validation_0-error:0.010035
# [180]	validation_0-error:0.010015
# [181]	validation_0-error:0.010005
# [182]	validation_0-error:0.010005
# [183]	validation_0-error:0.009965
# [184]	validation_0-error:0.009995
# [185]	validation_0-error:0.010005
# [186]	validation_0-error:0.01002
# [187]	validation_0-error:0.010015
# [188]	validation_0-error:0.009995
# [189]	validation_0-error:0.00997
# [190]	validation_0-error:0.009965
# [191]	validation_0-error:0.01002
# [192]	validation_0-error:0.01002
# [193]	validation_0-error:0.010005
# [194]	validation_0-error:0.01005
# [195]	validation_0-error:0.010061
# [196]	validation_0-error:0.01004
# [197]	validation_0-error:0.01004
# [198]	validation_0-error:0.010081
# [199]	validation_0-error:0.010076
# Stopping. Best iteration:
# [99]	validation_0-error:0.009763
#
# model4 predicting....
# d:\python35\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# sub scoring....
# precision: 0.8029445073612684, recall: 0.6023789294817332, ant_score: 0.7019541206457094
# out scoring...
# d:\python35\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# precision: 0.6774734488541084, recall: 0.46083650190114067, ant_score: 0.49490494296577947

# %%
import pickle
with open("xgd_500n9d01l_cv4.bat","wb") as f:
    pickle.dump(xgb_500n9d01l_list,f)

# %%
metrics.precision_score(test_y,predict_y),metrics.recall_score(test_y,predict_y)
# Out:
# (0.6774734488541084, 0.46083650190114067)

# %%
predict_probas = pd.DataFrame(predict_probas).T
predict_scores = predict_probas.mean(axis = 1).values

# retest the cv_model
ant_score(test_y,predict_scores)
# Out:
# 0.5168441064638783

# %%
# conduct final outer test
testa_data = pd.read_csv('../data/full_size/atec_anti_fraud_test_a.csv',index_col = 0)

# split time
testa_data['day'] = testa_data['date'].apply(lambda x:int(str(x)[6:]))
testa_data['weekday'] =testa_data['date'].apply(date2weekday)
testa_data = testa_data.drop(columns=['date'])

# predict
print('predicting on final outer testset.....')
scores = [] # store score predicted by every cv model
for model in xgb_500n9d01l_list:
    score = model.predict_proba(testa_data)[:,1]
    scores.append(score)

final_result = pd.DataFrame({'score':pd.DataFrame(scores).T.mean(axis=1).values},index=testa_data.index)
final_result.to_csv('../submission/time_split_xgb500n9d0.1l.csv')
# Out:
# predicting on final outer testset.....

# %%
final_result = pd.DataFrame({'score':pd.DataFrame(scores).T.mean(axis=1).values},index=testa_data.index)
final_result.to_csv('../submission/time_split_xgb500n9d0.1l.csv')
